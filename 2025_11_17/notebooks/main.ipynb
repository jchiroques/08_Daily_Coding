# %%
from os import scandir

def ls2(path=''):
    return [file.name for file in scandir(path)]

ls2('../datos/gatos/fotos')
# Out:
# ['gato_1.jpeg', 'gato_2.jpeg', 'gato_3.jpeg', 'gato_4.jpeg']

# %%
import cv2

# Cargamos el modelo para cada patron de detección hay un modelo diferente.
fase_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalcatface.xml')

# Cargamos la imagen a leer
img = cv2.imread('../datos/gatos/fotos/gato_1.jpg')
#gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img

gray
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 8
#       6 # Cargamos la imagen a leer
#       7 img = cv2.imread('../datos/gatos/fotos/gato_1.jpg')
# ----> 8 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      10 gray
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
